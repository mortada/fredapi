# %% [markdown]
# # Search for Data Series
#
# You can always search for data series on the FRED website. But sometimes it can be more convenient to search programmatically.
# `fredapi` provides a `search()` method that does a fulltext search and returns a `DataFrame` of results.

# %%
from fredapi import Fred

# %%
fred = Fred(api_key='insert api key here')

# %%
search_pot_gdp = fred.search('potential gdp')

# %%
search_pot_gdp.T.head()
# Out:
# series id                                         GDPPOT  \
# id                                                GDPPOT
# realtime_start                       2021-11-12 00:00:00
# realtime_end                         2021-11-12 00:00:00
# title              Real Potential Gross Domestic Product
# observation_start                    1949-01-01 00:00:00
#
# series id                                           NGDPPOT  \
# id                                                  NGDPPOT
# realtime_start                          2021-11-12 00:00:00
# realtime_end                            2021-11-12 00:00:00
# title              Nominal Potential Gross Domestic Product
# observation_start                       1949-01-01 00:00:00
#
# series id                                                 GDPC1CTMLR  \
# id                                                        GDPC1CTMLR
# realtime_start                                   2021-11-12 00:00:00
# realtime_end                                     2021-11-12 00:00:00
# title              Longer Run FOMC Summary of Economic Projection...
# observation_start                                2009-02-18 00:00:00
#
# series id                                      NROU  \
# id                                             NROU
# realtime_start                  2021-11-12 00:00:00
# realtime_end                    2021-11-12 00:00:00
# title              Noncyclical Rate of Unemployment
# observation_start               1949-01-01 00:00:00
#
# series id                                                  GDPC1MDLR  \
# id                                                         GDPC1MDLR
# realtime_start                                   2021-11-12 00:00:00
# realtime_end                                     2021-11-12 00:00:00
# title              Longer Run FOMC Summary of Economic Projection...
# observation_start                                2015-06-17 00:00:00
#
# series id                                                     NROUST  \
# id                                                            NROUST
# realtime_start                                   2021-11-12 00:00:00
# realtime_end                                     2021-11-12 00:00:00
# title              Natural Rate of Unemployment (Short-Term) (DIS...
# observation_start                                1949-01-01 00:00:00
#
# series id                                                  GDPC1RHLR  \
# id                                                         GDPC1RHLR
# realtime_start                                   2021-11-12 00:00:00
# realtime_end                                     2021-11-12 00:00:00
# title              Longer Run FOMC Summary of Economic Projection...
# observation_start                                2009-02-18 00:00:00
#
# series id                                                  GDPC1RMLR  \
# id                                                         GDPC1RMLR
# realtime_start                                   2021-11-12 00:00:00
# realtime_end                                     2021-11-12 00:00:00
# title              Longer Run FOMC Summary of Economic Projection...
# observation_start                                2009-02-18 00:00:00
#
# series id                                                 GDPC1CTHLR  \
# id                                                        GDPC1CTHLR
# realtime_start                                   2021-11-12 00:00:00
# realtime_end                                     2021-11-12 00:00:00
# title              Longer Run FOMC Summary of Economic Projection...
# observation_start                                2009-02-18 00:00:00
#
# series id                                                  GDPC1RLLR  \
# id                                                         GDPC1RLLR
# realtime_start                                   2021-11-12 00:00:00
# realtime_end                                     2021-11-12 00:00:00
# title              Longer Run FOMC Summary of Economic Projection...
# observation_start                                2009-02-18 00:00:00
#
# series id                                                 GDPC1CTLLR
# id                                                        GDPC1CTLLR
# realtime_start                                   2021-11-12 00:00:00
# realtime_end                                     2021-11-12 00:00:00
# title              Longer Run FOMC Summary of Economic Projection...
# observation_start                                2009-02-18 00:00:00
